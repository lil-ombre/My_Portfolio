# %%
import pandas as pd

# %%
df = pd.read_csv('sms+spam+collection/SMSSpamCollection', sep='\t')
df
# Out:
#        ham  \
# 0      ham
# 1     spam
# 2      ham
# 3      ham
# 4     spam
# ...    ...
# 5566  spam
# 5567   ham
# 5568   ham
# 5569   ham
# 5570   ham
#
#      Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                         Ok lar... Joking wif u oni...
# 1     Free entry in 2 a wkly comp to win FA Cup fina...
# 2     U dun say so early hor... U c already then say...
# 3     Nah I don't think he goes to usf, he lives aro...
# 4     FreeMsg Hey there darling it's been 3 week's n...
# ...                                                 ...
# 5566  This is the 2nd time we have tried 2 contact u...
# 5567               Will ü b going to esplanade fr home?
# 5568  Pity, * was in mood for that. So...any other s...
# 5569  The guy did some bitching but I acted like i'd...
# 5570                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5571 entries, 0 to 5570
# Data columns (total 2 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   ham                                                                                                              5571 non-null   object
#  1   Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...  5571 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.columns = ['output', 'email']

# %%
df
# Out:
#      output                                              email
# 0       ham                      Ok lar... Joking wif u oni...
# 1      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2       ham  U dun say so early hor... U c already then say...
# 3       ham  Nah I don't think he goes to usf, he lives aro...
# 4      spam  FreeMsg Hey there darling it's been 3 week's n...
# ...     ...                                                ...
# 5566   spam  This is the 2nd time we have tried 2 contact u...
# 5567    ham               Will ü b going to esplanade fr home?
# 5568    ham  Pity, * was in mood for that. So...any other s...
# 5569    ham  The guy did some bitching but I acted like i'd...
# 5570    ham                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# output    0
# email     0
# dtype: int64

# %%
df.output.value_counts()
# Out:
# output
# ham     4824
# spam     747
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df[df.duplicated()]
# Out:
#      output                                              email
# 102     ham  As per your request 'Melle Melle (Oru Minnamin...
# 153     ham  As per your request 'Melle Melle (Oru Minnamin...
# 206     ham  As I entered my cabin my PA said, '' Happy B'd...
# 222     ham                             Sorry, I'll call later
# 325     ham                   No calls..messages..missed calls
# ...     ...                                                ...
# 5523   spam  You are awarded a SiPix Digital Camera! call 0...
# 5534    ham  I know you are thinkin malaria. But relax, chi...
# 5538    ham                         Just sleeping..and surfing
# 5552    ham                        Hahaha..use your brain dear
# 5557    ham                             Sorry, I'll call later
#
# [403 rows x 2 columns]

# %%
X = df['email']
y = df['output']

# %%
y
# Out:
# 0        ham
# 1       spam
# 2        ham
# 3        ham
# 4       spam
#         ...
# 5566    spam
# 5567     ham
# 5568     ham
# 5569     ham
# 5570     ham
# Name: output, Length: 5571, dtype: object

# %%
df['output'] = df['output'].map({'ham': 0, 'spam': 1})
df
# Out:
#       output                                              email
# 0          0                      Ok lar... Joking wif u oni...
# 1          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2          0  U dun say so early hor... U c already then say...
# 3          0  Nah I don't think he goes to usf, he lives aro...
# 4          1  FreeMsg Hey there darling it's been 3 week's n...
# ...      ...                                                ...
# 5566       1  This is the 2nd time we have tried 2 contact u...
# 5567       0               Will ü b going to esplanade fr home?
# 5568       0  Pity, * was in mood for that. So...any other s...
# 5569       0  The guy did some bitching but I acted like i'd...
# 5570       0                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=43, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

X_train_vec = vectorizer.fit_transform(X_train)

# %%
X_test_vec = vectorizer.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
MNB_Model = MultinomialNB()

# %%
MNB_Model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = MNB_Model.predict(X_test_vec)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9614349775784753

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix
# Out:
# array([[965,   0],
#        [ 43, 107]], dtype=int64)

# %%
class_report = classification_report(y_test, y_pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       965
#         spam       1.00      0.71      0.83       150
#
#     accuracy                           0.96      1115
#    macro avg       0.98      0.86      0.91      1115
# weighted avg       0.96      0.96      0.96      1115

# %%
new_email = ["Win $$$ FREE CASH NOW! Click this link FAST!"]
new_email_vec = vectorizer.transform(new_email)

# %%
MNB_Model.predict(new_email_vec)
# Out:
# array(['ham'], dtype='<U4')

# %%
new_email2 = ["Win $$$ FREE CASH NOW! Click this link FAST!"]
new_email_vec2 = vectorizer.transform(new_email)

# %%
MNB_Model.predict(new_email_vec2)
# Out:
# array(['ham'], dtype='<U4')
